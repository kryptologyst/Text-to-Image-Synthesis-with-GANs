# %% [markdown]
# # Text-to-Image GAN Experimentation
#
# This notebook provides an interactive environment for experimenting with the text-to-image GAN model.

# %%
import torch
import matplotlib.pyplot as plt
import numpy as np
from src.models.text_to_image_gan import TextToImageGAN
from src.utils.device import get_device, set_seed, print_device_info

# Set device and seed
device = get_device("auto")
set_seed(42)
print_device_info()
